# %%
# !pip install psycopg2
import psycopg2
#  add email
'''server = smtplib.SMTP('smtp.gmail.com',587)
server.starttls()
server.login('connectusjecmohit132@gmail.com','owjsnkodweasxjcc' )
'''
DB_NAME = "Ghardekho"
DB_USER = "postgres"
DB_PASS = "github@0"
DB_HOST = "localhost"
DB_PORT = "5432"
conn = psycopg2.connect(database=DB_NAME, user=DB_USER, password=DB_PASS,
                        host=DB_HOST, port=DB_PORT)
print("Database connected successfully")
 
cur = conn.cursor()
cur.execute("""
            DROP TABLE CUSTOMER,BORKER,PROPERTY,APPOINTMENT [CASCADE]
            """)
cur.execute("""create table customer(
                C_ID Serial primary key,
                C_NAME VARCHAR(50),
                MOBILE_NO CHAR(10) UNIQUE ,
                EMAIL_ID VARCHAR(50) UNIQUE,
                PASSWORD VARCHAR(10)
             )   
            """)
cur.execute("""create table BORKER(
                B_ID Serial primary key,
                B_NAME VARCHAR(50) NOT NULL,
                MOBILE_NO CHAR(10) NOT NULL ,
                EMAIL_ID VARCHAR(50) UNIQUE ,
                PASSWORD VARCHAR(10) NOT NULL,
                ADDRESS TEXT
             ); 
           """) 
cur.execute ("""ALTER TABLE customer
             ADD CONSTRAINT customer_unique UNIQUE ( MOBILE_NO ,EMAIL_ID);""")           
cur.execute("""create table PROPERTY(
                P_ID SERIAL PRIMARY KEY,
                TOTAL_SQFT NUMERIC NOT NULL,
                PRICE   INTEGER,
                AREA VARCHAR(50) NOT NULL,
                ADDRESS VARCHAR(50) NOT NULL,
                SIZE SMALLINT,
                BALCONY SMALLINT,
                AVAILABILITY DATE NOT NULL,
                BATH SMALLINT NOT NULL,
                B_ID INTEGER REFERENCES BORKER(B_ID) ON DELETE SET NULL,  
             );
            """)
cur.execute ("""
              CREATE TABLE APPOINTMENT(
                APP_ID SERIAL PRIMARY KEY,
                C_ID INTEGER REFERENCES CUSTOMER(C_ID),
                B_ID INTEGER REFERENCES BORKER(B_ID),
                P_ID INTEGER REFERENCES PROPERTY(P_ID),
                A_DATE  DATE NOT NULL
                )            
            """)
cur.execute ("""ALTER TABLE BORKER
               ADD CONSTRAINT BORKER_unique UNIQUE ( MOBILE_NO ,EMAIL_ID);""")     
conn.commit()
conn.close()
'''create table customer(
                C_ID Serial primary key,
                C_NAME VARCHAR(50),
                MOBILE_NO CHAR(10) UNIQUE ,
                EMAIL_ID VARCHAR(50) UNIQUE,
                PASSWORD VARCHAR(10)
             )   
              ALTER TABLE customer
ADD CONSTRAINT customer_unique UNIQUE ( MOBILE_NO ,EMAIL_ID); 
             create table BORKER(
                B_ID Serial primary key,
                B_NAME VARCHAR(50) NOT NULL,
                MOBILE_NO CHAR(10) NOT NULL ,
                EMAIL_ID VARCHAR(50) UNIQUE ,
                PASSWORD VARCHAR(10) NOT NULL,
                ADDRESS TEXT
             );  
             ALTER TABLE BORKER
ADD CONSTRAINT BORKER_unique UNIQUE ( MOBILE_NO ,EMAIL_ID);    
              create table PROPERTY(
                P_ID SERIAL PRIMARY KEY,
                TOTAL_SQFT NUMERIC NOT NULL,
                PRICE   INTEGER,
                AREA VARCHAR(50) NOT NULL,
                ADDRESS VARCHAR(50) NOT NULL,
                SIZE SMALLINT,
                BALCONY SMALLINT,
                AVAILABILITY DATE NOT NULL,
                BATH SMALLINT NOT NULL,
                B_ID INTEGER REFERENCES BORKER(B_ID) ON DELETE SET NULL,  
             );
            '''
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting psycopg2
#   Downloading psycopg2-2.9.4-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.4
# Database connected successfully
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# Input In [3], in <cell line: 18>()
#      15 print("Database connected successfully")
#      17 cur = conn.cursor()
# ---> 18 cur.execute("""
#      19             DROP TABLE CUSTOMER,BORKER,PROPERTY,APPOINTMENT [CASCADE]
#      20             """)
#      21 cur.execute("""create table customer(
#      22                 C_ID Serial primary key,
#      23                 C_NAME VARCHAR(50),
#    (...)
#      27              )
#      28             """)
#      29 cur.execute("""create table BORKER(
#      30                 B_ID Serial primary key,
#      31                 B_NAME VARCHAR(50) NOT NULL,
#    (...)
#      36              );
#      37            """)
#
# SyntaxError: syntax error at or near "["
# LINE 2: ...   DROP TABLE CUSTOMER,BORKER,PROPERTY,APPOINTMENT [CASCADE]
#                                                               ^
